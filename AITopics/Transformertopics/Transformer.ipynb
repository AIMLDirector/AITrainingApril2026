# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.9.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (2026.2.28)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (0.24.1)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from transformers) (4.67.3)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 17.8 MB/s eta 0:00:001m14.9 MB/s eta 0:00:01
# Downloading huggingface_hub-1.9.0-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.4/637.4 kB 13.7 MB/s eta 0:00:00
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading hf_xet-1.4.3-cp37-abi3-macosx_11_0_arm64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 12.6 MB/s eta 0:00:0031m9.3 MB/s eta 0:00:01
# Installing collected packages: safetensors, hf-xet, fsspec, filelock, huggingface-hub, tokenizers, transformers
# Successfully installed filelock-3.25.2 fsspec-2026.3.0 hf-xet-1.4.3 huggingface-hub-1.9.0 safetensors-0.7.0 tokenizers-0.22.2 transformers-5.5.0
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow torch
# Out:
# Requirement already satisfied: tensorflow in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (2.21.0)
# Requirement already satisfied: torch in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: filelock in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from torch) (3.25.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from torch) (2026.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
import torch

# %%
classifier = pipeline("sentiment-analysis")
# classifier = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|█████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 6790.70it/s]

# %%
import torch
import transformers
from transformers import pipeline

# This line explicitly links torch to the transformers namespace
transformers.utils.import_utils._is_torch_available = lambda: True 

classifier = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# Loading weights: 100%|█████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 4498.33it/s]

# %%
pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.21.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tf-keras) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras) (0.46.3)
# Requirement already satisfied: rich in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (14.3.3)
# Requirement already satisfied: namex in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.2)
# Downloading tf_keras-2.21.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 210.4 kB/s eta 0:00:00 kB/s eta 0:00:01:03
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.21.0
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
classifier(
    [ " I dont like apple products",
     " i am learning NLP",
     "I am working on GenAI",
    ]
)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.991593599319458},
#  {'label': 'POSITIVE', 'score': 0.9928638935089111},
#  {'label': 'POSITIVE', 'score': 0.9907621741294861}]

# %%
classifier1 = pipeline("zero-shot-classification")
result = classifier1(
    "We are learning Gen ai and agentic AI",
    candidate_labels= ["education","Business","science"],
)
defaultscore=0.5
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|█████████████████████████████████████████████████████████| 515/515 [00:00<00:00, 6740.86it/s]
# {'sequence': 'We are learning Gen ai and agentic AI',
#  'labels': ['education', 'science', 'Business'],
#  'scores': [0.6406950950622559, 0.2871307134628296, 0.07217414677143097]}

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_beams=5,
    num_return_sequences=1,
)
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fetching 2 files:   0%|                                                                      | 0/2 [00:13<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      49 with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                   initargs=(lk,)) as ex:
# ---> 51     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     618 if timeout is None:
# --> 619     yield _result_or_cancel(fs.pop())
#     620 else:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     316 try:
# --> 317     return fut.result(timeout)
#     318 finally:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     354 if timeout is None:
# --> 355     waiter.acquire()
#     356     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 from transformers import pipeline
# ----> 3 generator = pipeline("text-generation")
#       4 generator(
#       5     "In this course, we will teach you how to",
#       6     max_length=30,
#       7     num_beams=5,
#       8     num_return_sequences=1,
#       9 )
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/pipelines/__init__.py:806, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     804 if isinstance(model, str):
#     805     model_classes = targeted_task["pt"]
# --> 806     model = load_model(
#     807         adapter_path if adapter_path is not None else model,
#     808         model_classes=model_classes,
#     809         config=config,
#     810         task=task,
#     811         **hub_kwargs,
#     812         **model_kwargs,
#     813     )
#     815 hub_kwargs["_commit_hash"] = model.config._commit_hash
#     817 # Check which preprocessing classes the pipeline uses
#     818 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/pipelines/base.py:232, in load_model(model, config, model_classes, task, **model_kwargs)
#     229 kwargs = model_kwargs.copy()
#     231 try:
# --> 232     model = model_class.from_pretrained(model, **kwargs)
#     233     # Stop loading on the first successful load.
#     234     break
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:387, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     385     if model_class.config_class == config.sub_configs.get("text_config", None):
#     386         config = config.get_text_config()
# --> 387     return model_class.from_pretrained(
#     388         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     389     )
#     390 raise ValueError(
#     391     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     392     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     393 )
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/modeling_utils.py:4054, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4049     logger.warning_once(
#    4050         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4051     )
#    4052     use_kernels = True
# -> 4054 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4055     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4056     variant=variant,
#    4057     gguf_file=gguf_file,
#    4058     use_safetensors=use_safetensors,
#    4059     download_kwargs=download_kwargs_with_commit,
#    4060     user_agent=user_agent,
#    4061     is_remote_code=cls.is_remote_code(),
#    4062     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4063     tqdm_class=tqdm_class,
#    4064 )
#    4066 is_quantized = hf_quantizer is not None
#    4068 if gguf_file:
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/modeling_utils.py:737, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     735 sharded_metadata = None
#     736 if is_sharded:
# --> 737     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#     738         pretrained_model_name_or_path,
#     739         resolved_archive_file,
#     740         cache_dir=cache_dir,
#     741         force_download=force_download,
#     742         proxies=proxies,
#     743         local_files_only=local_files_only,
#     744         token=token,
#     745         user_agent=user_agent,
#     746         revision=revision,
#     747         subfolder=subfolder,
#     748         _commit_hash=commit_hash,
#     749         tqdm_class=tqdm_class,
#     750     )
#     751 else:
#     752     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/utils/hub.py:879, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, subfolder, _commit_hash, tqdm_class, **deprecated_kwargs)
#     875     return shard_filenames, sharded_metadata
#     877 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#     878 # or download the files
# --> 879 cached_filenames = cached_files(
#     880     pretrained_model_name_or_path,
#     881     shard_filenames,
#     882     cache_dir=cache_dir,
#     883     force_download=force_download,
#     884     proxies=proxies,
#     885     local_files_only=local_files_only,
#     886     token=token,
#     887     user_agent=user_agent,
#     888     revision=revision,
#     889     subfolder=subfolder,
#     890     _commit_hash=_commit_hash,
#     891     tqdm_class=tqdm_class,
#     892 )
#     894 return cached_filenames, sharded_metadata
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     422         hf_hub_download(
#     423             path_or_repo_id,
#     424             filenames[0],
#    (...)    434             tqdm_class=tqdm_class,
#     435         )
#     436     else:
# --> 437         snapshot_download(
#     438             path_or_repo_id,
#     439             allow_patterns=full_filenames,
#     440             repo_type=repo_type,
#     441             revision=revision,
#     442             cache_dir=cache_dir,
#     443             user_agent=user_agent,
#     444             force_download=force_download,
#     445             proxies=proxies,
#     446             token=token,
#     447             local_files_only=local_files_only,
#     448             tqdm_class=tqdm_class,
#     449         )
#     451 except Exception as e:
#     452     # We cannot recover from them
#     453     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/huggingface_hub/_snapshot_download.py:451, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, dry_run)
#     429 def _inner_hf_hub_download(repo_file: str) -> None:
#     430     results.append(
#     431         hf_hub_download(  # type: ignore
#     432             repo_id,
#    (...)    448         )
#     449     )
# --> 451 thread_map(
#     452     _inner_hf_hub_download,
#     453     filtered_repo_files,
#     454     desc=tqdm_desc,
#     455     max_workers=max_workers,
#     456     tqdm_class=tqdm_class,
#     457 )
#     459 bytes_progress.set_description("Download complete")
#     461 if dry_run:
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:49, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      46 lock_name = kwargs.pop("lock_name", "")
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
# ---> 49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
#      51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_beams=5,
    num_return_sequences=1,
)
# Out:
# Loading weights: 100%|█████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 5679.60it/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to use Python, a powerful programming language, to solve real-world problems. We will start with the basics and gradually build up to more complex concepts. By the end of this course, you will have a solid understanding of Python and be able to use it to solve problems in your own projects.\n\n### Installing and Importing Libraries\n\nBefore we begin, we need to install and import some libraries. Libraries are pre-written code that we can use to perform specific tasks. In Python, we use the `pip` command to install libraries. Once we have installed the libraries, we can import them into our code using the `import` statement.\n\nHere is an example of how to install and import the `numpy` library:\n```python\n!pip install numpy\nimport numpy as np\n```\nIn this example, we are using the `pip` command to install the `numpy` library and then importing it into our code using the `import` statement. We are also using the `as` keyword to give the `numpy` library a shorter name, which makes our code easier to read.\n\n### Defining Functions\n\nIn Python, we can define functions using the `def` keyword. A function is a block of code that performs'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|█████████████████████████████████████████████████████████| 106/106 [00:00<00:00, 5421.97it/s]
# RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.1961996853351593,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052749648690224,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]
